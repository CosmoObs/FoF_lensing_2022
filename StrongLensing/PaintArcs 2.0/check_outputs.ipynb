# %%
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
file = fits.open('arceinstein.fits')
plt.imshow(file[0].data)
plt.show()

# %%
file_back = fits.open('backgroundeinstein.fits')
plt.imshow(file_back[0].data)
plt.show()

# %%
file_arc = fits.open('arc_conveinstein.fits')
plt.imshow(file_arc[0].data)
plt.show()

# %%
file_arc = fits.open('arc_conv_noise_bkgeinstein.fits')
plt.imshow(file_arc[0].data)
plt.show()

# %%
file_arc = fits.open('arc_conv_noiseeinstein.fits')
plt.imshow(file_arc[0].data)
plt.show()
